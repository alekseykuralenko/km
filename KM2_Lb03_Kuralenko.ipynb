# %% [markdown]
# # Лабораторная работа 3
# # Анимация движения секущей прямой к заданной линии на плоскости

# %% [markdown]
# Кураленко Алексей 16.03

# %%
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ## Задание 3.1. Анимированное построение линии на плоскости

# %% [markdown]
# #### *построение графика функции y(x) = $sin(x)^4$*

# %%
# !pip install sympy
# Out:
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\envs\widgets_env\lib\site-packages (1.13.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\envs\widgets_env\lib\site-packages (from sympy) (1.3.0)

# %%
import sympy

# %%
import ipympl

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
def y(x):
 return np.sin(x)**4

# %%
x_min = 1.; x_max = 5.; step = 0.05

# %%
x_array = np.arange(x_min, x_max, step)
y_array = y(x_array)

# %%
matrix = np.transpose([x_array, y_array])

# %%
fig1 = plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y_min, y_max = np.min(y_array), np.max(y_array)
ax1 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
# Out:
# (np.float64(0.5),
#  np.float64(5.5),
#  np.float64(-0.499999995004082),
#  np.float64(1.4996930655910048))

# %%
line1, = ax1.plot([],[],'b')
print(type(line1))
line1.get_xdata(), line1.get_ydata()
# Out:
# <class 'matplotlib.lines.Line2D'>
# (array([], dtype=float64), array([], dtype=float64))

# %%
def at_frame1(point):
 """добавляет к объекту line1 точку с координатами (point[0],point[1])

 Arguments :

 point : массив из двух элементов

 Returns : None
 """
 x_coord = list(line1.get_xdata())
 y_coord = list(line1.get_ydata())

 x_coord.append(point[0])
 y_coord.append(point[1])

 line1.set_data(x_coord, y_coord)

# %%
# ?line1.set_data
# Out:
# Signature: line1.set_data(*args)
# Docstring:
# Set the x and y data.
#
# Parameters
# ----------
# *args : (2, N) array or two 1D arrays
#
# See Also
# --------
# set_xdata
# set_ydata
# File:      c:\users\lenovo\anaconda3\envs\widgets_env\lib\site-packages\matplotlib\lines.py
# Type:      method

# %%
help(at_frame1)
# Out:
# Help on function at_frame1 in module __main__:
#
# at_frame1(point)
#     добавляет к объекту line1 точку с координатами (point[0],point[1])
#
#     Arguments :
#
#     point : массив из двух элементов
#
#     Returns : None

# %%
# ?at_frame1
# Out:
# Signature: at_frame1(point)
# Docstring:
# добавляет к объекту line1 точку с координатами (point[0],point[1])
#
# Arguments :
#
# point : массив из двух элементов
#
# Returns : None
# File:      c:\users\lenovo\appdata\local\temp\ipykernel_20888\1118907211.py
# Type:      function

# %%
print(at_frame1.__doc__)
# Out:
# добавляет к объекту line1 точку с координатами (point[0],point[1])
#
#  Arguments :
#
#  point : массив из двух элементов
#
#  Returns : None

# %%
fig1 = plt.figure()
ax1 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
line1, = ax1.plot([], [],'b')
FuncAnimation(fig1, at_frame1, frames=matrix, repeat=False, interval=50)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ## Реализация Задания 3.1b

# %%
def x1(t):
 return np.log(t + np.sqrt(t**2 + 1))

# %%
def y1(t):
 return t * np.sqrt(t**2 + 1)

# %%
t= np.arange(1.,5.,0.01)
x1_array=x1(t)
y1_array=y1(t)
matrix01 = np.transpose([x1_array, y1_array])
fig01 = plt.figure()
y1_min, y1_max = np.min(y1_array), np.max(y1_array)
x1_min, x1_max = np.min(x1_array), np.max(x1_array)
ax01 = plt.axes()
plt.axis([x1_min-0.5, x1_max+0.5, y1_min-0.5, y1_max+0.5])
line01, = ax01.plot([],[],'b')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def at_frame01(point):
 x_coord = list(line01.get_xdata())
 y_coord = list(line01.get_ydata())

 x_coord.append(point[0])
 y_coord.append(point[1])

 line01.set_data(x_coord, y_coord)

# %%
fig01 = plt.figure()
ax01 = plt.axes()
plt.axis([x1_min-0.5, x1_max+0.5, y1_min-0.5, y1_max+0.5])
line01, = ax01.plot([], [],'b')
FuncAnimation(fig01, at_frame01, frames=matrix01, repeat=False, interval=30)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ## Задание 3.2. Движение точки по линии на плоскости

# %%
def at_frame01(point):
 x_coord = list(line01.get_xdata())
 y_coord = list(line01.get_ydata())

 x_coord.append(point[0])
 y_coord.append(point[1])

 line01.set_data(x_coord, y_coord)

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
line01, = ax01.plot([], [],'b')
line2, = ax2.plot([], [],'go')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Определим пользовательскую функцию одного аргумента `at_frame2` , которая
# будет вызываться в каждом кадре анимации.

# %%
def at_frame2(point):
 """задает объект line2 точкой с координатами (point[0],point[1])

 Arguments :

 point : массив из двух элементов

 Returns : None
 """
 line2.set_data([point[0]],[point[1]])

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
def init():
 """создает начальное состояние графической области"""
global line2

line1, = ax2.plot(x_array, y_array,'b')
line2, = ax2.plot([], [],'go')
plt.legend([r'$y(x) = \sin(x)^4$','Мovable point'])
FuncAnimation(fig2, at_frame2, frames=matrix, init_func=init, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ## Реализация анимации для функции из 3.1b

# %%
# сделать движение точки

# %%
fig3 = plt.figure()
ax3 = plt.axes()
plt.axis([x1_min-0.5, x1_max+0.5, y1_min-0.5, y1_max+0.5])
# Out:
# (np.float64(0.38137358701954294),
#  np.float64(2.8104752918167675),
#  np.float64(0.9142135623730951),
#  np.float64(25.89517828269772))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
line11, = ax3.plot(x1_array, y1_array,'b') # объект для графика функции
line22, = ax3.plot([], [],'go') # объект для точки

# %%
def at_frame3(point):
     line22.set_data([point[0]], [point[1]])

# %%
fig3 = plt.figure()
ax3 = plt.axes()
plt.axis([x1_min-0.5, x1_max+0.5, y1_min-0.5, y1_max+0.5])
def init1():
    """Создает начальное состояние графической области"""
    global line22 
    
    line11, = ax3.plot(x1_array, y1_array,'b')
    line22, = ax3.plot([], [],'go') 
    
FuncAnimation(fig3, at_frame3, frames=matrix01, init_func=init1, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# # Задание 3.3. Движение секущей прямой к заданной линии на плоскости (версия 1)

# %%
fig4 = plt.figure()
ax4 = plt.axes()
plt.axis([x_min-1, x_max+1, y_min-1, y_max+1])
def init():
    global point_B, secant_line 

    curve, = ax4.plot(x_array, y_array,'b')

    A = np.array([x_array[0], y_array[0]])
    point_A, = ax4.plot(A[0],A[1],'ro')

    B = np.array([x_array[-1], y_array[-1]])
    point_B, = ax4.plot(B[0],B[1],'go')

    secant_p = [A + (B - A)*t for t in [-2, 2]]
    secant_p = np.array(secant_p)
    secant_line, = ax4.plot(secant_p[:,0], secant_p[:,1],'g')

    plt.legend([r'$y(x) = \sin(x)^4$','Unmovable point A','Мovable point B','Sec'])
def at_frame4(point):
    global point_B, secant_line
    A = np.array([x_array[0], y_array[0]])
    B = np.array([point[0],point[1]])
    point_B.set_data([point[0]],[point[1]])
    if B[0]==A[0]:
        t = sympy.Symbol('t')
        y_x=sympy.sin(t)**4
        y_difx = sympy.diff(y_x, t) 
        k=y_difx.subs(t, A[0])
        y_kasstart = np.array([A[0],A[1]])
        y_kasend = np.array([A[0]+1,k+A[1]])
        y_kas=[y_kasstart+ (y_kasend-y_kasstart)*t for t in [-10, 10]]
        y_kas = np.array(y_kas)
        secant_line.set_data(y_kas[:,0], y_kas[:,1])
        secant_line.set_color('r')
    else:
        secant_p = [A + (B - A)*l for l in [-9, 9]] # две точки секущей прямой, прох
        secant_p = np.array(secant_p)
        secant_line.set_data(secant_p[:,0], secant_p[:,1])
FuncAnimation(fig4, at_frame4, frames=matrix[::-1], init_func=init, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ## Задание 3.4. Движение секущей прямой к заданной линии на плоскости (версия 2)

# %%
fig5 = plt.figure()
ax5 = plt.axes()
plt.axis([x1_min-1, x1_max+1, y1_min-1, y1_max+1])
def init5():
    global point_B3, secant_line3

    curve, = ax5.plot(x1_array, y1_array,'b') 

    A3 = np.array([x1_array[0], y1_array[0]])
    point_A3, = ax5.plot(A3[0],A3[1],'ro')

    B3 = np.array([x1_array[-1], y1_array[-1]])
    point_B3, = ax5.plot(B3[0],B3[1],'go') 

    secant_p3 = [A3 + (B3 - A3)*t for t in [-2, 2]] 
    secant_p3 = np.array(secant_p3)
    secant_line3, = ax5.plot(secant_p3[:,0], secant_p3[:,1],'g') 

def at_frame5(point):
    global point_B3, secant_line3
    A3 = np.array([x1_array[0], y1_array[0]])
    B3 = np.array([point[0],point[1]])
    point_B3.set_data([point[0]],[point[1]])
    if B3[0]==A3[0]:
        t = sympy.Symbol('t')
        x_d=sympy.log(t + sympy.sqrt(t**2 + 1))
        y_d =t * sympy.sqrt(t**2 + 1)
        x_difx = sympy.diff(x_d, t)
        y_difx = sympy.diff(y_d, t) 
        k=y_difx.subs(t, t_array[0])/x_difx.subs(t, t_array[0])
        y_kasstart = np.array([A3[0],A3[1]])
        y_kasend = np.array([A3[0]+1,k+A3[1]])
        y_kas=[y_kasstart+ (y_kasend-y_kasstart)*t for t in [-1, 2]]
        y_kas = np.array(y_kas)
        secant_line3.set_data(y_kas[:,0], y_kas[:,1])
        secant_line3.set_color('r')
    else:
        secant_p3 = [A3 + (B3 - A3)*l for l in [-2, 2]]
        secant_p3 = np.array(secant_p3)
        secant_line3.set_data(secant_p3[:,0], secant_p3[:,1])
FuncAnimation(fig5, at_frame5, frames=matrix01[::-1], init_func=init5, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')
